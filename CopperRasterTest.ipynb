# %%
import rasterio

# %%
import rasterio.plot
import pyproj
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
barc = rasterio.open("./copper_20020608_barc.tif")

# %%
barc.indexes
# Out:
# (1,)

# %%
barc1 = barc.read(1)

# %%
plt.imshow(barc1)
