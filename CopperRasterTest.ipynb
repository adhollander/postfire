# %%
import rasterio

# %%
import rasterio.plot
import pyproj
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
import shapefile

# %%
barc = rasterio.open("./copper_20020608_barc.tif")

# %%
barc.indexes
# Out:
# (1,)

# %%
barc1 = barc.read(1)

# %%
plt.imshow(barc1)

# %%
fireboundary = shapefile.Reader("datasets/Copper_only")

# %%
plt.imshow(barc1)
for shape in fireboundary.shapes():
    points = shape.points
    plt.Polygon(points, fill=False, edgecolor="r")
    #ax.add_patch(ap)

# %%
barc.crs
# Out:
# CRS({'init': 'epsg:26711'})

# %%
nsgm = rasterio.open("./nsgeomorphon.tif")

# %%
nsgm1 = nsgm.read(1)

# %%
from descartes import PolygonPatch

# %%
import fiona

# %%
with fiona.open("datasets/Copper_only.shp", "r") as coppershp:
    features = [feature["geometry"] for feature in coppershp]

# %%
rasterio.plot.show((nsgm),1)
ax = plt.gca()
#for shape in fireboundary.shapes():
#    points = shape.points
#    plt.Polygon(points, fill=False, edgecolor="r")
#    ax.add_patch(ap)
#patches = [PolygonPatch(feature, edgecolor="red", facecolor="none", linewidth=2) for feature in features]
#ax.add_collection(matplotlib.collections.PatchCollection(patches, match_original=True))

patches = [PolygonPatch(feature) for feature in features]
ax.add_collection(matplotlib.collections.PatchCollection(patches))

# %%
features
# Out:
# [{'type': 'Polygon',
#   'coordinates': [[(145463.9224999994, -376474.3104999997),
#     (145471.98310000077, -376486.8208999997),
#     (145482.0623999983, -376483.90020000003),
#     (145485.74570000172, -376487.3674999997),
#     (145505.7628000006, -376506.2105999999),
#     (145539.1224000007, -376510.35030000005),
#     (145554.16340000182, -376499.57079999987),
#     (145558.8834999986, -376486.67030000035),
#     (145584.01410000026, -376473.12129999977),
#     (145610.0139000006, -376487.6116000004),
#     (145610.77369999886, -376513.2112999996),
#     (145606.0425999984, -376526.1107999999),
#     (145606.87249999866, -376551.71050000004),
#     (145645.39319999889, -376558.20129999984),
#     (145678.31309999898, -376546.9517000001),
#     (145695.8735000007, -376536.27109999955),
#     (145723.8035000004, -376530.3015999999),
#     (145744.53409999982, -376539.8317999998),
#     (145765.60350000113, -376559.6122000003),
#     (145794.27340000123, -376579.23149999976),
# ...

# %%
patches

# %%
dir(patches)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
patches.count
# Out:
# <function list.count>

# %%
patches.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-b673772afd4b> in <module>
# ----> 1 patches.count()
#
# TypeError: count() takes exactly one argument (0 given)
